# %% [markdown]
# # 00 — Pull des données (S3 via DVC)
#
# **Fin d'étape** : sauvegarde `mlops/artifacts/pipeline/steps/00_pull_data/state.json` (chemin du dataset).

# %%
import os
from dvc.api import DVCFileSystem

os.environ["AWS_ACCESS_KEY_ID"] = os.getenv("ACCESS_KEY_ID")
os.environ["AWS_SECRET_ACCESS_KEY"] = os.getenv("SECRET_ACCESS_KEY")
os.environ["AWS_DEFAULT_REGION"] = "auto"
print("AWS_ACCESS_KEY_ID:", os.getenv("AWS_ACCESS_KEY_ID"))
print("AWS_SECRET_ACCESS_KEY:", os.getenv("AWS_SECRET_ACCESS_KEY"))

repo = "https://git.razano.dev/llabeyrie/mlops-dataset.git"

fs = DVCFileSystem(repo, rev="main")
# Out:
# AWS_ACCESS_KEY_ID: 865482db75904ec1534df45f060ae514
# AWS_SECRET_ACCESS_KEY: 7d3ee9da1bf59caffc3e34717360c44a76935b6c98d7b8474b6b406365d82eb

# %%
fs.get("cards", "../data/raw/cards", recursive=True)

n_png = len(list(fs.glob("../data/raw/cards/**/*.png")))

print(f"Pull terminé — {n_png} PNG sous {'../data/raw/cards'}")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/s3fs/core.py:169, in _error_wrapper(func, args, kwargs, retries)
#     168 try:
# --> 169     return await func(*args, **kwargs)
#     170 except S3_RETRYABLE_ERRORS as e:
#
# File ~/miniforge3/lib/python3.12/site-packages/aiobotocore/context.py:36, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      35     await resolve_awaitable(hook())
# ---> 36 return await func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/aiobotocore/client.py:436, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     435     error_class = self.exceptions.from_code(error_code)
# --> 436     raise error_class(parsed_response, operation_name)
#     437 else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:767, in _load_from_storage(trie, entry, storage_info)
#     766 if isinstance(storage, ObjectStorage):
# --> 767     _load_from_object_storage(trie, entry, storage)
#     768 else:
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:703, in _load_from_object_storage(trie, root_entry, storage)
#     701     raise FileNotFoundError
# --> 703 obj = Tree.load(storage.odb, root_entry.hash_info, hash_name=storage.odb.hash_name)
#     705 dirs = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/hashfile/tree.py:193, in Tree.load(cls, odb, hash_info, hash_name)
#     192 try:
# --> 193     with obj.fs.open(obj.path, "r") as fobj:
#     194         raw = json.load(fobj)
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_objects/fs/base.py:323, in FileSystem.open(self, path, mode, **kwargs)
#     322     kwargs.pop("encoding", None)
# --> 323 return self.fs.open(path, mode=mode, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/spec.py:1340, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1334     text_kwargs = {
#    1335         k: kwargs.pop(k)
#    1336         for k in ["encoding", "errors", "newline"]
#    1337         if k in kwargs
#    1338     }
#    1339     return io.TextIOWrapper(
# -> 1340         self.open(
#    1341             path,
#    1342             mode,
#    1343             block_size=block_size,
#    1344             cache_options=cache_options,
#    1345             compression=compression,
#    1346             **kwargs,
#    1347         ),
#    1348         **text_kwargs,
#    1349     )
#    1350 else:
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/spec.py:1352, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1351 ac = kwargs.pop("autocommit", not self._intrans)
# -> 1352 f = self._open(
#    1353     path,
#    1354     mode=mode,
#    1355     block_size=block_size,
#    1356     autocommit=ac,
#    1357     cache_options=cache_options,
#    1358     **kwargs,
#    1359 )
#    1360 if compression is not None:
#
# File ~/miniforge3/lib/python3.12/site-packages/s3fs/core.py:816, in S3FileSystem._open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, size, requester_pays, cache_options, **kwargs)
#     814     cache_type = self.default_cache_type
# --> 816 return S3File(
#     817     self,
#     818     path,
#     819     mode,
#     820     block_size=block_size,
#     821     acl=acl,
#     822     version_id=version_id,
#     823     fill_cache=fill_cache,
#     824     s3_additional_kwargs=kw,
#     825     cache_type=cache_type,
#     826     autocommit=autocommit,
#     827     requester_pays=requester_pays,
#     828     cache_options=cache_options,
#     829     size=size,
#     830 )
#
# File ~/miniforge3/lib/python3.12/site-packages/s3fs/core.py:2556, in S3File.__init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays, cache_options, size)
#    2555         self.version_id = self.details.get("VersionId")
# -> 2556 super().__init__(
#    2557     s3,
#    2558     path,
#    2559     mode,
#    2560     block_size,
#    2561     autocommit=autocommit,
#    2562     cache_type=cache_type,
#    2563     cache_options=cache_options,
#    2564     size=size,
#    2565 )
#    2566 self.s3 = self.fs  # compatibility
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/spec.py:1926, in AbstractBufferedFile.__init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1925 else:
# -> 1926     self.size = self.details["size"]
#    1927 self.cache = caches[cache_type](
#    1928     self.blocksize, self._fetch_range, self.size, **cache_options
#    1929 )
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/spec.py:1939, in AbstractBufferedFile.details(self)
#    1938 if self._details is None:
# -> 1939     self._details = self.fs.info(self.path)
#    1940 return self._details
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     117 self = obj or args[0]
# --> 118 return sync(self.loop, func, *args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/miniforge3/lib/python3.12/site-packages/s3fs/core.py:1732, in S3FileSystem._info(self, path, bucket, key, refresh, version_id)
#    1731 try:
# -> 1732     out = await self._call_s3(
#    1733         "head_object",
#    1734         self.kwargs,
#    1735         Bucket=bucket,
#    1736         Key=key,
#    1737         **version_id_kw(version_id),
#    1738         **self.req_kw,
#    1739     )
#    1740     return {
#    1741         "ETag": out.get("ETag", ""),
#    1742         "LastModified": out.get("LastModified", ""),
#    (...)   1748         "ContentType": out.get("ContentType"),
#    1749     }
#
# File ~/miniforge3/lib/python3.12/site-packages/s3fs/core.py:460, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     459 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 460 return await _error_wrapper(
#     461     method, kwargs=additional_kwargs, retries=self.retries
#     462 )
#
# File ~/miniforge3/lib/python3.12/site-packages/s3fs/core.py:215, in _error_wrapper(func, args, kwargs, retries)
#     214 err = translate_boto_error(err)
# --> 215 raise err
#
# PermissionError: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# DataIndexDirError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fs.get("cards", "../data/raw/cards", recursive=True)
#       3 n_png = len(list(fs.glob("../data/raw/cards/**/*.png")))
#       5 print(f"Pull terminé — {n_png} PNG sous {'../data/raw/cards'}")
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc/fs/dvc.py:502, in _DVCFileSystem.get(self, rpath, lpath, recursive, callback, maxdepth, batch_size, **kwargs)
#     492 def get(
#     493     self,
#     494     rpath,
#    (...)    500     **kwargs,
#     501 ):
# --> 502     self._get(
#     503         rpath,
#     504         lpath,
#     505         recursive=recursive,
#     506         callback=callback,
#     507         maxdepth=maxdepth,
#     508         batch_size=batch_size,
#     509         **kwargs,
#     510     )
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc/fs/dvc.py:552, in _DVCFileSystem._get(self, rpath, lpath, recursive, callback, maxdepth, batch_size, **kwargs)
#     549 _files: dict[FileSystem, list[tuple[str, str, Optional[dict]]]]
#     550 _files = defaultdict(list)
# --> 552 for root, dirs, files in self.walk(rpath, maxdepth=maxdepth, detail=True):
#     553     if files:
#     554         callback.set_size((callback.size or 0) + len(files))
#
# File ~/miniforge3/lib/python3.12/site-packages/fsspec/spec.py:432, in AbstractFileSystem.walk(self, path, maxdepth, topdown, on_error, **kwargs)
#     430 detail = kwargs.pop("detail", False)
#     431 try:
# --> 432     listing = self.ls(path, detail=True, **kwargs)
#     433 except (FileNotFoundError, OSError) as e:
#     434     if on_error == "raise":
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc/fs/dvc.py:391, in _DVCFileSystem.ls(self, path, detail, dvc_only, **kwargs)
#     389             dvc_infos[""] = dvc_info
#     390         else:
# --> 391             for info in dvc_fs.ls(dvc_path, detail=True):
#     392                 dvc_infos[dvc_fs.name(info["name"])] = info
#     394 fs_infos = {}
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_objects/fs/base.py:518, in FileSystem.ls(self, path, detail, **kwargs)
#     517 def ls(self, path, detail=False, **kwargs):
# --> 518     return self.fs.ls(path, detail=detail, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/fs.py:171, in DataFileSystem.ls(self, path, detail, **kwargs)
#     165     return [
#     166         self.join(path, key[-1])
#     167         for key in self.index.ls(root_key, detail=False)
#     168     ]
#     170 entries = []
# --> 171 for key, info in self.index.ls(root_key, detail=True):
#     172     info["name"] = self.join(path, key[-1])
#     173     entries.append(info)
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:920, in DataIndex.ls(self, root_key, detail)
#     919 def ls(self, root_key: DataIndexKey, detail=True):
# --> 920     self._ensure_loaded(root_key)
#     921     if detail:
#     922         yield from (
#     923             (key, self._info_from_entry(key, entry))
#     924             for key, entry in self._trie.ls(root_key, with_values=True)
#     925         )
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:917, in DataIndex._ensure_loaded(self, prefix)
#     915 entry = self.get(prefix)
#     916 if entry and entry.meta and entry.meta.isdir and not entry.loaded:
# --> 917     self._load(prefix, entry)
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:866, in DataIndex._load(self, key, entry)
#     864     _load_from_storage(self._trie, entry, storage_info)
#     865 except DataIndexDirError as exc:
# --> 866     self.onerror(entry, exc)
#     867     return
#     869 entry.loaded = True
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:794, in DataIndex.__init__.<locals>._onerror(_, exc)
#     793 def _onerror(_, exc):
# --> 794     raise exc
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:864, in DataIndex._load(self, key, entry)
#     861     return
#     863 try:
# --> 864     _load_from_storage(self._trie, entry, storage_info)
#     865 except DataIndexDirError as exc:
#     866     self.onerror(entry, exc)
#
# File ~/miniforge3/lib/python3.12/site-packages/dvc_data/index/index.py:782, in _load_from_storage(trie, entry, storage_info)
#     773         last_exc = exc
#     774         logger.debug(
#     775             "failed to load %s from storage %s (%s)",
#     776             entry.key,
#    (...)    779             exc_info=True,
#     780         )
# --> 782 raise DataIndexDirError(f"failed to load directory {entry.key}") from last_exc
#
# DataIndexDirError: failed to load directory ('cards',)

# %%
save_step_output("00_pull_data", {
    "cards_dir": rel_path(cards_dir),
    "n_png": n_png,
    "dvc_file": rel_path(cards_dvc),
})
